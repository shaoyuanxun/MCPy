# %% [markdown]
# ## Second-order Pointwise Convergence

# %% [markdown]
# #### Check that the log-log plot has a linear relationship with slope 2 when width(X) gets really small

# %%
x = 1
fun=lambda x: exp(x**3)
convergencePlot(x, fun)

# %%
x = 1
fun=lambda x: log(x**3)*sqrt(x)
convergencePlot(x, fun)

# %% [markdown]
# ### Satisfied!
